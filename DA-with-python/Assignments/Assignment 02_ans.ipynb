# %% [markdown]
# # Part -2 Python Basics (Conditional Statements)

# %% [markdown]
# 1) A company decided to give bonus of 5% to employee if his/her year of service is more than 5 years.
# Ask user for their salary and year of service and print the net bonus amount.

# %%
salary = int(input("Enter Salary"))
year = int(input("Enter your years of service"))
bonus = salary * 0.5

if year > 5:
    salary = salary + bonus
    print(salary)
else:
    print("wait for completing 5 years")
# Out:
# 15000.0

# %% [markdown]
# 2) Write a program to check whether a person is eligible for voting or not. (accept age from user) if age is greater than 17 eligible otherwise not eligible

# %%
age = int(input("enter age"))

if age > 17:
    print(age,"eligible for voting")
else:
    print(age,"not eligible")
# Out:
# 15 not eligible

# %% [markdown]
# 3) Write a program to check whether a number entered by user is even or odd.

# %%
num = int(input("enter number"))

if num % 2 == 0:
    print(num,"even")
else:
    print(num,"odd")
# Out:
# 5 odd

# %% [markdown]
# 4) Write a program to check whether a number is divisible by 7 or not.
# Show Answer

# %%
num = int(input("enter no"))

if num % 7 == 0:
    print(num,"divisible by 7")
else:
    print(num,"divisible by 7")
# Out:
# 77 divisible by 7

# %% [markdown]
# 5) Write a program to display
# "Hello" if a number entered by user is a multiple of five , otherwise print "Bye".

# %%
num = int(input("enter no"))

if num % 5 == 0:
    print(num,"hello")
else:
    print(num,"bye")
# Out:
# hello

# %% [markdown]
# 7) Write a program to display the last digit of a number.

# %%
num = int(input("enter no"))
last_dig = num % 10

print(last_dig)
# Out:
# 1

# %% [markdown]
# 9) Take values of length and breadth of a rectangle from user and print if it is square or rectangle.

# %%
len = int(input("enter length"))
bret = int(input("enter breadth"))

if len == bret:
    print("square")
else:
    print("rectangle")
# Out:
# rectangle

# %% [markdown]
# 10) Take two int values from user and print greatest among them.

# %%
num1 = int(input("enter 1st no"))
num2 = int(input("enter 2nd no"))

if num1 > num2:
    print(f"{num1} is greater than {num2}")
else:
    print(f"{num2} is greater than {num1}")
# Out:
# 76 is greater than 56

# %% [markdown]
# 11) A shop will give discount of 10% if the cost of purchased quantity is more than 1000.
# Ask user for quantity
# Suppose, one unit will cost 100.
# Judge and print total cost for user.

# %%
Quantiy = int(input("Enter the quantity of purchased product"))
total = Quantiy * 100

if total > 1000:
    disc = total * 0.10
    p = total - disc
    print(p,"Is the price with 10% discount")

else:
    print(total,"Is the price without discount")
# Out:
# 1000 Is the price without discount

# %% [markdown]
# 12) A school has following rules for grading system:
#
# a. Below 25 - F
#
# b. 25 to 45 - E
#
# c. 45 to 50 - D
#
# d. 50 to 60 - C
#
# e. 60 to 80 - B
#
# f. Above 80 - A
#
# Ask user to enter marks and print the corresponding grade.

# %%
marks = int(input("Enter marks"))

if marks > 80:
    grade = "A"
elif marks > 60 and marks < 80:
    grade = "B"
elif marks > 50 and marks < 60:
    grade = "C"
elif marks > 45 and marks < 50:
    grade = "D"
elif marks > 25 and marks < 45:
    grade = "E"
else:
    grade = "fail"

print(f"your grade is {grade} Acc to marks {marks}")
# Out:
# your grade is E Acc to marks 26

# %% [markdown]
# 14)A student will not be allowed to sit in exam if his/her attendence is less than 75%.
#
# Take following input from user
#
# - Number of classes held
#
# - Number of classes attended.
#
# And print
#
# - percentage of class attended
#
# - Is student is allowed to sit in exam or not.

# %%
total_c = int(input("Enter no of total class"))
attend_c = int(input("Enter no of total class"))

perc = attend_c / total_c 
perc1 = perc * 100

if perc > 0.75:
    perc1 = perc * 100
    print(f"you are allowed in exam, attendence is {perc1}")
else:
    print(f"you are not allowed in exam, attendence is {perc1}")
# Out:
# you are  not allowed in exam, attendence is 33.33333333333333

# %% [markdown]
# 15) Modify the above question to allow student to sit if he/she has medical cause. Ask user if he/she has medical cause or not ( 'Y' or 'N' ) and print accordingly.

# %%
total_c = int(input("Enter no of total class"))
attend_c = int(input("Enter no of total class"))

perc = attend_c / total_c 
perc1 = perc * 100

med = input("""If you have medical cause just type "y" """)
if med == "Y" or med == "y":
    print(f"you are allowed it exam due to medical cause")
else:
    if perc > 0.75:
        perc1 = perc * 100
        print(f"you are allowed in exam, attendence is {perc1}")
    else:
        print(f"you are not allowed in exam, attendence is {perc1}")
# Out:
# you are allowed it exam due to medical cause

# %% [markdown]
# 16) Write a program to check if a year is leap year or not.
#
# If a year is divisible by 4 then it is leap year but if the year is century year like 2000, 1900, 2100 then it must be divisible by 400.

# %%
year = int(input("enter year"))

if year % 4 == 0:
    print("leap year")
else:
    print("not leap year")
# Out:
# leap year

# %% [markdown]
# 17) Ask user to enter age, gender ( M or F ), marital status ( Y or N ) and then using following rules print their place of service.
#
# if employee is female, then she will work only in urban areas.
#
# if employee is a male and age is in between 20 to 40 then he may work in anywhere
#
# if employee is male and age is in between 40 t0 60 then he will work in urban areas only.
#
# And any other input of age should print "ERROR"

# %%
age = int(input("enter age"))
gender = input(""" type your gender just click "M" for male, "F" for female """)
marital = input(""" type your marital status just click "Y" for married, "N" for single """)

if gender == "F":
    print("You work only in urban areas")
else:
    if age > 20 and age < 40:
        print("you work in anywhere")
    elif age > 40 and age < 60:
        print("You work only in urban areas")
    else:
        print("error")
# Out:
# You work only in urban areas

# %% [markdown]
# 6) Write a program to calculate the electricity bill (accept number of unit from user) according to the following criteria :
#      Unit                                                     Price
# uptp 100 units                                             no charge
# Next 200 units                                              Rs 5 per unit
# After 200 units                                             Rs 10 per unit
# (For example if input unit is 350 than total bill amount is Rs.3500
# (For example if input unit is 97 than total bill amount is Rs.0
# (For example if input unit is 150 than total bill amount is Rs.750

# %%
units = int(input("enter units"))

if units >= 0 and units <= 100:
    print("no charge")
elif units > 100 and units <= 200:
    bill = units * 5
    print(f"your bill is {bill}") 
elif units > 200:
    bill = units * 10
    print(f"your bill is {bill}") 

else:
    print("error")
# Out:
# your bill is 750

# %% [markdown]
# 13) Take input of age of 3 people by user and determine oldest and youngest among them.

# %%
a = int(input("enter age 1"))
b = int(input("enter age 2"))
c = int(input("enter age 3"))

if (a > b and a > c):
    print(f"A is oldest {a}")
    if b > c :
        print(f"C is youngest {c}")
    else:
        print(f"B is youngest {b}")

elif (b > a and b > c ):
    print(f"B is oldest {b}")
    if a > c :
        print(f"C is youngest {c}")
    else:
        print(f"A is youngest {a}")

else:
    print(f"C is oldest {c}")
    if a > b:
        print(f"B is youngest {b}")
    else:
        print(f"A is youngest {a}")
# Out:
# C is oldest 12
# A is youngest 10
